# %% [markdown]
# #### **Parte Teórica**:
#
#
# 1. **¿Qué es un modelo anidado y cómo se diferencia de uno no anidado?**
#
#
# 2. **Explica la utilidad y propósito de una prueba F anidada.**
#
#
# 3. **¿Cómo se tratan las variables categóricas en la regresión lineal?**
#
#
# 4. **Describe qué es una interacción entre variables y cómo puede afectar el modelo.**
#
# 5. **¿Qué mide la bondad de ajuste en la regresión?**
#
#
# 6. **Explica la importancia del análisis de residuos y qué se puede inferir de él.**

# %% [markdown]
# #### **Parte Práctica**:
#
# Vamos usar la base de datos tips de seaborn en este caso.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import faraway.utils
import faraway.datasets.sexab

# %%
# Carga del dataset
df = sns.load_dataset('tips')

# %% [markdown]
# 1. **Exploración Inicial**:
#    - Visualiza las primeras filas del dataset.
#    - Realiza un pairplot para ver la relación entre las variables numéricas.

# %% [markdown]
# 2. **Modelos Anidados**:
#    - Crea un modelo básico con `total_bill` como predictor.
#    - Añade `size` como predictor adicional y compara los modelos.

# %% [markdown]
# 3. **Pruebas F Anidadas**:
#    - Realiza una prueba F anidada entre los dos modelos.

# %% [markdown]
# 4. **Variables Categóricas**:
#    - Añade la variable categórica `sex` al modelo mediante codificación dummy.

# %% [markdown]
# 5. **Intereacciones**:
#    - Añade una interacción entre `total_bill` y `size` al modelo.

# %% [markdown]
# 6. **Pruebas de Bondad de Ajuste**:
#    - Compara R-squared, R-square adj y el MSE entre los cuatro modelos.

# %% [markdown]
# 7. **Análisis de Residuos**:
#    - Grafica los residuos frente a los valores ajustados para el último modelo.
#    - Realiza un QQ-Plot para verificar la normalidad de los residuos.
